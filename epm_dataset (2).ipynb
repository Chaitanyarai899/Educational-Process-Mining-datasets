# 36                  5.0                 1.5                 24.5
# 37                  4.0                 3.0                 25.0
# 38                  4.0                 1.5                 10.0
# 39                  0.0                 1.5                 25.0
# 40                  5.0                 3.0                 25.0
# 41                  0.0                 0.0                  8.0
# 42                  8.0                 3.0                 25.0
# 43                  0.0                 0.0                  0.0
# 44                  0.0                 0.0                  0.0
# 45                  0.0                 1.5                 24.0
# 46                 10.0                 3.0                 12.0
# 47                  4.0                 1.5                 10.0
# 48                  0.0                 0.0                  0.0
# 49                  8.0                 1.5                 24.0
# 50                  0.0                 0.0                  0.0
# 51                  0.0                 0.0                  7.0
#
#     ES 6.2\n(15 points)  TOTAL\n(100 points)
# 0                    15                 85.0
# 1                    15                 82.0
# 2                    10                 52.5
# 3                    10                 59.0
# 4                    15                 90.0
# 5                    15                 67.5
# 6                    15                 67.0
# 7                    15                 97.0
# 8                    10                 62.0
# 9                    10                 58.5
# 10                    0                 32.5
# 11                   10                 74.5
# 12                   13                 79.5
# 13                   15                 97.0
# 14                    0                  7.0
# 15                    5                 75.5
# 16                   13                 79.0
# 17                    0                 19.0
# 18                   15                 41.0
# 19                   15                 98.0
# 20                   10                 50.0
# 21                    0                 12.0
# 22                   15                 71.5
# 23                    0                  8.5
# 24                   10                 70.5
# 25                    8                 71.5
# 26                    0                 40.0
# 27                    0                 22.0
# 28                   10                 69.0
# 29                   10                 86.0
# 30                   10                 80.5
# 31                    3                 62.5
# 32                   15                 95.0
# 33                    5                 28.5
# 34                    0                 18.0
# 35                   12                 93.5
# 36                   10                 78.0
# 37                   15                 87.0
# 38                    0                 35.5
# 39                   12                 82.0
# 40                   15                 94.0
# 41                   13                 46.0
# 42                   15                 96.0
# 43                    0                 16.5
# 44                    0                 19.5
# 45                   13                 66.0
# 46                   10                 77.5
# 47                    8                 66.5
# 48                    0                  9.5
# 49                   10                 83.0
# 50                    0                 18.5
# 51                   15                 45.5
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df1= pd.read_excel('/content/drive/MyDrive/intermediate_grades.xlsx')
print(df1)
# Out:
#      Student Id  Session 2  Session 3  Session 4  Session 5  Session 6
# 0             1        5.0        0.0        4.5        4.0       2.25
# 1             2        4.0        3.5        4.5        4.0       1.00
# 2             3        3.5        3.5        4.5        4.0       0.00
# 3             4        6.0        4.0        5.0        3.5       2.75
# 4             5        5.0        4.0        5.0        4.0       2.75
# ..          ...        ...        ...        ...        ...        ...
# 110         111        3.0        0.0        0.0        3.0       0.00
# 111         112        0.0        0.0        0.0        0.0       0.00
# 112         113        0.0        0.0        0.0        0.0       0.00
# 113         114        0.0        0.0        0.0        0.0       0.00
# 114         115        0.0        0.0        0.0        0.0       0.00
#
# [115 rows x 6 columns]

# %%
# describing the final grades data

df.describe()
# Out:
#        Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  \
# count   52.000000            52.000000            52.000000
# mean    55.538462             1.884615             2.865385
# std     30.733811             0.351682             0.595040
# min      3.000000             0.000000             0.000000
# 25%     28.750000             2.000000             3.000000
# 50%     57.500000             2.000000             3.000000
# 75%     83.500000             2.000000             3.000000
# max    106.000000             2.000000             3.000000
#
#        ES 2.1\n(2 points)  ES 2.2\n(3 points)  ES 3.1\n(1 points)  \
# count           52.000000           52.000000           52.000000
# mean             1.432692            1.259615            0.942308
# std              0.569045            1.077808            0.235435
# min              0.000000            0.000000            0.000000
# 25%              1.000000            0.000000            1.000000
# 50%              1.500000            1.500000            1.000000
# 75%              2.000000            2.000000            1.000000
# max              2.000000            3.000000            1.000000
#
#        ES 3.2\n(2 points)  ES 3.3\n(2 points)  ES 3.4\n(2 points)  \
# count           52.000000           52.000000           52.000000
# mean             1.903846            1.423077            1.721154
# std              0.408710            0.914934            0.688943
# min              0.000000            0.000000            0.000000
# 25%              2.000000            0.000000            2.000000
# 50%              2.000000            2.000000            2.000000
# 75%              2.000000            2.000000            2.000000
# max              2.000000            2.000000            2.000000
#
#        ES 3.5\n(3 points)  ES 4.1\n(15 points)  ES 4.2\n(10 points)  \
# count           52.000000            52.000000            52.000000
# mean             2.375000             9.769231             6.413462
# std              1.195888             5.784921             3.320644
# min              0.000000             0.000000             0.000000
# 25%              3.000000             3.000000             4.000000
# 50%              3.000000            13.000000             7.000000
# 75%              3.000000            15.000000            10.000000
# max              3.000000            15.000000            10.000000
#
#        ES 5.1\n(2 points)  ES 5.2\n(10 points)  ES 5.3\n(3 points)  \
# count           52.000000            52.000000           52.000000
# mean             1.057692             4.192308            1.826923
# std              0.958214             4.114958            1.271423
# min              0.000000             0.000000            0.000000
# 25%              0.000000             0.000000            0.000000
# 50%              1.000000             4.000000            1.750000
# 75%              2.000000             8.000000            3.000000
# max              2.000000            10.000000            3.000000
#
#        ES 6.1\n(25 points)  ES 6.2\n(15 points)  TOTAL\n(100 points)
# count            52.000000            52.000000            52.000000
# mean             12.153846             8.846154            60.067308
# std               9.587849             5.869110            28.157301
# min               0.000000             0.000000             7.000000
# 25%               2.750000             2.250000            38.875000
# 50%              12.000000            10.000000            67.250000
# 75%              24.000000            15.000000            82.000000
# max              25.000000            15.000000            98.000000

# %%
# checking if there exists any NULL values in the dataset

df.isnull().sum()
# Out:
# Student ID             0
# ES 1.1 \n(2 points)    0
# ES 1.2 \n(3 points)    0
# ES 2.1\n(2 points)     0
# ES 2.2\n(3 points)     0
# ES 3.1\n(1 points)     0
# ES 3.2\n(2 points)     0
# ES 3.3\n(2 points)     0
# ES 3.4\n(2 points)     0
# ES 3.5\n(3 points)     0
# ES 4.1\n(15 points)    0
# ES 4.2\n(10 points)    0
# ES 5.1\n(2 points)     0
# ES 5.2\n(10 points)    0
# ES 5.3\n(3 points)     0
# ES 6.1\n(25 points)    0
# ES 6.2\n(15 points)    0
# TOTAL\n(100 points)    0
# dtype: int64

# %%
# checking if there exists any NULL values in the dataset

df1.isnull().sum()
# Out:
# Student Id    0
# Session 2     0
# Session 3     0
# Session 4     0
# Session 5     0
# Session 6     0
# dtype: int64

# %%
plt.rcParams['figure.figsize'] = (15, 15)
sns.heatmap(df, annot = True)
plt.title('Heatmap for the Final Grades Data',fontsize = 30)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 15)
sns.heatmap(df1, cmap = 'Blues', annot = True)
plt.title('Heatmap for the Final Grades Data',fontsize = 30)
plt.show()

# %%
df.columns
# Out:
# Index(['Student ID', 'ES 1.1 \n(2 points)', 'ES 1.2 \n(3 points)',
#        'ES 2.1\n(2 points)', 'ES 2.2\n(3 points)', 'ES 3.1\n(1 points)',
#        'ES 3.2\n(2 points)', 'ES 3.3\n(2 points)', 'ES 3.4\n(2 points)',
#        'ES 3.5\n(3 points)', 'ES 4.1\n(15 points)', 'ES 4.2\n(10 points)',
#        'ES 5.1\n(2 points)', 'ES 5.2\n(10 points)', 'ES 5.3\n(3 points)',
#        'ES 6.1\n(25 points)', 'ES 6.2\n(15 points)', 'TOTAL\n(100 points)'],
#       dtype='object')

# %%
# looking at the distribution of the total marks of the students

plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(df['TOTAL\n(100 points)'], color = 'skyblue')
plt.title('Distribution of Total Marks among 52 Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# <ipython-input-158-20ab1739b5d0>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TOTAL\n(100 points)'], color = 'skyblue')

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(df1['Session 2'], color = 'purple')
plt.title('Distribution of Session2 Marks among 115  Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# <ipython-input-159-83d7f20c1eb3>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Session 2'], color = 'purple')

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(df1['Session 3'], color = 'violet')
plt.title('Distribution of Session 3 among 115  Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# <ipython-input-160-4cd4891a54d5>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Session 3'], color = 'violet')

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(df1['Session 4'], color = 'pink')
plt.title('Distribution of Session 4 Marks among 115  Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# <ipython-input-161-49b82ca9808f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Session 4'], color = 'pink')

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(df1['Session 5'], color = 'red')
plt.title('Distribution of Session 5 Marks among 115 Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# <ipython-input-162-b7097db846c4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Session 5'], color = 'red')

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(df1['Session 6'], color = 'yellow')
plt.title('Distribution of Session 6 Marks among 115 Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# <ipython-input-163-2b788031423a>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Session 6'], color = 'yellow')

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 1.1 \n(2 points)'], c = 'r')
# sns.barplot(data1['Student ID'], data1['ES 1.1 \n(2 points)'])
plt.title('Time Series for Students Performance in Test-1', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 1.2 \n(3 points)'], c ='blue')
plt.title('Time Series for Students Performance in different Test-2', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x= df['Student ID'], y =df['ES 2.1\n(2 points)'], c ='green')

plt.title('Time Series for Students Performance in Test-3', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y =df['ES 2.2\n(3 points)'], c ='orange')

plt.title('Time Series for Students Performance in Test-4', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 3.1\n(1 points)'], c = 'black')

plt.title('Time Series for Students Performance in Test-5', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 3.2\n(2 points)'], c = 'purple')

plt.title('Time Series for Students Performance in Test-6', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 3.3\n(2 points)'], c = 'brown')

plt.title('Time Series for Students Performance in Test-7', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 3.4\n(2 points)'], c = 'magenta')

plt.title('Time Series for Students Performance in Test-8', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
df.head()
# Out:
#    Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  ES 2.1\n(2 points)  \
# 0           3                  2.0                    3                 1.0
# 1           6                  2.0                    3                 2.0
# 2           7                  2.0                    3                 1.0
# 3          10                  2.0                    3                 2.0
# 4          13                  2.0                    3                 2.0
#
#    ES 2.2\n(3 points)  ES 3.1\n(1 points)  ES 3.2\n(2 points)  \
# 0                 2.0                   1                   2
# 1                 3.0                   1                   2
# 2                 1.5                   1                   2
# 3                 1.5                   1                   2
# 4                 1.5                   1                   2
#
#    ES 3.3\n(2 points)  ES 3.4\n(2 points)  ES 3.5\n(3 points)  \
# 0                   2                 2.0                 3.0
# 1                   2                 0.0                 3.0
# 2                   0                 0.0                 3.0
# 3                   0                 2.0                 3.0
# 4                   2                 2.0                 3.0
#
#    ES 4.1\n(15 points)  ES 4.2\n(10 points)  ES 5.1\n(2 points)  \
# 0                 15.0                 10.0                   1
# 1                 15.0                  7.0                   2
# 2                  5.0                  4.0                   0
# 3                 11.0                  1.0                   2
# 4                 14.5                 10.0                   2
#
#    ES 5.2\n(10 points)  ES 5.3\n(3 points)  ES 6.1\n(25 points)  \
# 0                  5.0                 3.0                 18.0
# 1                  9.0                 3.0                 13.0
# 2                  0.0                 3.0                 17.0
# 3                 10.0                 1.5                  7.0
# 4                  2.0                 3.0                 25.0
#
#    ES 6.2\n(15 points)  TOTAL\n(100 points)
# 0                   15                 85.0
# 1                   15                 82.0
# 2                   10                 52.5
# 3                   10                 59.0
# 4                   15                 90.0

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x =df['Student ID'], y = df['ES 3.5\n(3 points)'], c = 'lightgreen')

plt.title('Time Series for Students Performance in Test-9', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x =df['Student ID'], y = df['ES 5.2\n(10 points)'], c = 'red')

plt.title('Time Series for Students Performance in Test-12', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 5.3\n(3 points)'], c = 'lightblue')

plt.title('Time Series for Students Performance in Test-13', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 6.1\n(25 points)'], c = 'crimson')

plt.title('Time Series for Students Performance in Test-14', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.scatter(x = df['Student ID'], y = df['ES 6.2\n(15 points)'], c = 'black')

plt.title('Time Series for Students Performance in Test-15', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# plotting a pairplot for intermediate grades data

sns.pairplot(df1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student ID          52 non-null     int64
#  1   ES 1.1
# (2 points)  52 non-null     float64
#  2   ES 1.2
# (3 points)  52 non-null     int64
#  3   ES 2.1
# (2 points)   52 non-null     float64
#  4   ES 2.2
# (3 points)   52 non-null     float64
#  5   ES 3.1
# (1 points)   52 non-null     int64
#  6   ES 3.2
# (2 points)   52 non-null     int64
#  7   ES 3.3
# (2 points)   52 non-null     int64
#  8   ES 3.4
# (2 points)   52 non-null     float64
#  9   ES 3.5
# (3 points)   52 non-null     float64
#  10  ES 4.1
# (15 points)  52 non-null     float64
#  11  ES 4.2
# (10 points)  52 non-null     float64
#  12  ES 5.1
# (2 points)   52 non-null     int64
#  13  ES 5.2
# (10 points)  52 non-null     float64
#  14  ES 5.3
# (3 points)   52 non-null     float64
#  15  ES 6.1
# (25 points)  52 non-null     float64
#  16  ES 6.2
# (15 points)  52 non-null     int64
#  17  TOTAL
# (100 points)  52 non-null     float64
# dtypes: float64(11), int64(7)
# memory usage: 7.4 KB

# %%
df.drop(columns=[
    'Student ID',
],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-219-1cc093d1a1ea> in <cell line: 1>()
# ----> 1 df.drop(columns=[
#       2     'Student ID',
#       3 ],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['Student ID'] not found in axis"

# %%
df
# Out:
#     ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  ES 2.1\n(2 points)  \
# 0                   2.0                    3                 1.0
# 1                   2.0                    3                 2.0
# 2                   2.0                    3                 1.0
# 3                   2.0                    3                 2.0
# 4                   2.0                    3                 2.0
# 5                   2.0                    3                 1.0
# 6                   2.0                    3                 1.0
# 7                   2.0                    3                 1.0
# 8                   1.0                    3                 2.0
# 1                    15                 82.0    0.0
# 2                    10                 52.5    1.0
# 3                    10                 59.0    1.0
# 4                    15                 90.0    0.0
# 5                    15                 67.5    1.0
# 6                    15                 67.0    1.0
# 7                    15                 97.0    0.0
# 8                    10                 62.0    1.0
# 9                    10                 58.5    1.0
# 10                    0                 32.5    2.0
# 11                   10                 74.5    0.0
# 12                   13                 79.5    0.0
# 13                   15                 97.0    0.0
# 14                    0                  7.0    2.0
# 15                    5                 75.5    0.0
# 16                   13                 79.0    0.0
# 17                    0                 19.0    2.0
# 18                   15                 41.0    2.0
# 19                   15                 98.0    0.0
# 20                   10                 50.0    2.0
# 21                    0                 12.0    2.0
# 22                   15                 71.5    0.0
# 23                    0                  8.5    2.0
# 24                   10                 70.5    0.0
# 25                    8                 71.5    0.0
# 26                    0                 40.0    2.0
# 27                    0                 22.0    2.0
# 28                   10                 69.0    1.0
# 29                   10                 86.0    0.0
# 30                   10                 80.5    0.0
# 31                    3                 62.5    1.0
# 32                   15                 95.0    0.0
# 33                    5                 28.5    2.0
# 34                    0                 18.0    2.0
# 35                   12                 93.5    0.0
# 36                   10                 78.0    0.0
# 37                   15                 87.0    0.0
# 38                    0                 35.5    2.0
# 39                   12                 82.0    0.0
# 40                   15                 94.0    0.0
# 41                   13                 46.0    2.0
# 42                   15                 96.0    0.0
# 43                    0                 16.5    2.0
# 44                    0                 19.5    2.0
# 45                   13                 66.0    1.0
# 46                   10                 77.5    0.0
# 47                    8                 66.5    1.0
# 48                    0                  9.5    2.0
# 49                   10                 83.0    0.0
# 50                    0                 18.5    2.0
# 51                   15                 45.5    2.0

# %%
Good = df.loc[(df['TOTAL\n(100 points)'] >= 70.0)]
print(len(Good))

Fair = df.loc[(df['TOTAL\n(100 points)'] >= 51.0) & (df['TOTAL\n(100 points)'] <= 69.0)]
print(len(Fair))

Weak = df.loc[(df['TOTAL\n(100 points)'] <= 50.0)]
print(len(Weak))

# Assigning labels to the categories
df.loc[df['TOTAL\n(100 points)'] >= 70.0, 'label'] = 0
df.loc[(df['TOTAL\n(100 points)'] >= 51.0) & (df['TOTAL\n(100 points)'] <= 69.0), 'label'] = 1
df.loc[df['TOTAL\n(100 points)'] <= 50.0, 'label'] = 2


x = ['Good', 'Fair', 'Weak']
y = [len(Good), len(Fair), len(Weak)]
sns.set(rc={'figure.figsize':(12,8)})
ax = sns.barplot(x=x, y=y)
# Out:
# 24
# 10
# 18

# %%
X = df.drop(['label'],axis=1).values
Y = df['label'].values

# %%
df.head()
# Out:
#    ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  ES 2.1\n(2 points)  \
# 0                  2.0                    3                 1.0
# 1                  2.0                    3                 2.0
# 2                  2.0                    3                 1.0
# 3                  2.0                    3                 2.0
# 4                  2.0                    3                 2.0
#
#    ES 2.2\n(3 points)  ES 3.1\n(1 points)  ES 3.2\n(2 points)  \
# 0                 2.0                   1                   2
# 1                 3.0                   1                   2
# 2                 1.5                   1                   2
# 3                 1.5                   1                   2
# 4                 1.5                   1                   2
#
#    ES 3.3\n(2 points)  ES 3.4\n(2 points)  ES 3.5\n(3 points)  \
# 0                   2                 2.0                 3.0
# 1                   2                 0.0                 3.0
# 2                   0                 0.0                 3.0
# 3                   0                 2.0                 3.0
# 4                   2                 2.0                 3.0
#
#    ES 4.1\n(15 points)  ES 4.2\n(10 points)  ES 5.1\n(2 points)  \
# 0                 15.0                 10.0                   1
# 1                 15.0                  7.0                   2
# 2                  5.0                  4.0                   0
# 3                 11.0                  1.0                   2
# 4                 14.5                 10.0                   2
#
#    ES 5.2\n(10 points)  ES 5.3\n(3 points)  ES 6.1\n(25 points)  \
# 0                  5.0                 3.0                 18.0
# 1                  9.0                 3.0                 13.0
# 2                  0.0                 3.0                 17.0
# 3                 10.0                 1.5                  7.0
# 4                  2.0                 3.0                 25.0
#
#    ES 6.2\n(15 points)  TOTAL\n(100 points)  label
# 0                   15                 85.0    0.0
# 1                   15                 82.0    0.0
# 2                   10                 52.5    1.0
# 3                   10                 59.0    1.0
# 4                   15                 90.0    0.0

# %%
df.isna().sum()
# Out:
# ES 1.1 \n(2 points)    0
# ES 1.2 \n(3 points)    0
# ES 2.1\n(2 points)     0
# ES 2.2\n(3 points)     0
# ES 3.1\n(1 points)     0
# ES 3.2\n(2 points)     0
# ES 3.3\n(2 points)     0
# ES 3.4\n(2 points)     0
# ES 3.5\n(3 points)     0
# ES 4.1\n(15 points)    0
# ES 4.2\n(10 points)    0
# ES 5.1\n(2 points)     0
# ES 5.2\n(10 points)    0
# ES 5.3\n(3 points)     0
# ES 6.1\n(25 points)    0
# ES 6.2\n(15 points)    0
# TOTAL\n(100 points)    0
# label                  0
# dtype: int64

# %%
df.describe()
# Out:
#        Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  \
# count   52.000000            52.000000            52.000000
# mean    55.538462             1.884615             2.865385
# std     30.733811             0.351682             0.595040
# min      3.000000             0.000000             0.000000
# 25%     28.750000             2.000000             3.000000
# 50%     57.500000             2.000000             3.000000
# 75%     83.500000             2.000000             3.000000
# max    106.000000             2.000000             3.000000
#
#        ES 2.1\n(2 points)  ES 2.2\n(3 points)  ES 3.1\n(1 points)  \
# count           52.000000           52.000000           52.000000
# mean             1.432692            1.259615            0.942308
# std              0.569045            1.077808            0.235435
# min              0.000000            0.000000            0.000000
# 25%              1.000000            0.000000            1.000000
# 50%              1.500000            1.500000            1.000000
# 75%              2.000000            2.000000            1.000000
# max              2.000000            3.000000            1.000000
#
#        ES 3.2\n(2 points)  ES 3.3\n(2 points)  ES 3.4\n(2 points)  \
# count           52.000000           52.000000           52.000000
# mean             1.903846            1.423077            1.721154
# std              0.408710            0.914934            0.688943
# min              0.000000            0.000000            0.000000
# 25%              2.000000            0.000000            2.000000
# 50%              2.000000            2.000000            2.000000
# 75%              2.000000            2.000000            2.000000
# max              2.000000            2.000000            2.000000
#
#        ES 3.5\n(3 points)  ES 4.1\n(15 points)  ES 4.2\n(10 points)  \
# count           52.000000            52.000000            52.000000
# mean             2.375000             9.769231             6.413462
# std              1.195888             5.784921             3.320644
# min              0.000000             0.000000             0.000000
# 25%              3.000000             3.000000             4.000000
# 50%              3.000000            13.000000             7.000000
# 75%              3.000000            15.000000            10.000000
# max              3.000000            15.000000            10.000000
#
#        ES 5.1\n(2 points)  ES 5.2\n(10 points)  ES 5.3\n(3 points)  \
# count           52.000000            52.000000           52.000000
# mean             1.057692             4.192308            1.826923
# std              0.958214             4.114958            1.271423
# min              0.000000             0.000000            0.000000
# 25%              0.000000             0.000000            0.000000
# 50%              1.000000             4.000000            1.750000
# 75%              2.000000             8.000000            3.000000
# max              2.000000            10.000000            3.000000
#
#        ES 6.1\n(25 points)  ES 6.2\n(15 points)  TOTAL\n(100 points)  \
# count            52.000000            52.000000            52.000000
# mean             12.153846             8.846154            60.067308
# std               9.587849             5.869110            28.157301
# min               0.000000             0.000000             7.000000
# 25%               2.750000             2.250000            38.875000
# 50%              12.000000            10.000000            67.250000
# 75%              24.000000            15.000000            82.000000
# max              25.000000            15.000000            98.000000
#
#            label
# count  52.000000
# mean    0.884615
# std     0.899975
# min     0.000000
# 25%     0.000000
# 50%     1.000000
# 75%     2.000000
# max     2.000000

# %%
df.head()
# Out:
#    ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  ES 2.1\n(2 points)  \
# 0                  2.0                    3                 1.0
# 1                  2.0                    3                 2.0
# 2                  2.0                    3                 1.0
# 3                  2.0                    3                 2.0
# 4                  2.0                    3                 2.0
#
#    ES 2.2\n(3 points)  ES 3.1\n(1 points)  ES 3.2\n(2 points)  \
# 0                 2.0                   1                   2
# 1                 3.0                   1                   2
# 2                 1.5                   1                   2
# 3                 1.5                   1                   2
# 4                 1.5                   1                   2
#
#    ES 3.3\n(2 points)  ES 3.4\n(2 points)  ES 3.5\n(3 points)  \
# 0                   2                 2.0                 3.0
# 1                   2                 0.0                 3.0
# 2                   0                 0.0                 3.0
# 3                   0                 2.0                 3.0
# 4                   2                 2.0                 3.0
#
#    ES 4.1\n(15 points)  ES 4.2\n(10 points)  ES 5.1\n(2 points)  \
# 0                 15.0                 10.0                   1
# 1                 15.0                  7.0                   2
# 2                  5.0                  4.0                   0
# 3                 11.0                  1.0                   2
# 4                 14.5                 10.0                   2
#
#    ES 5.2\n(10 points)  ES 5.3\n(3 points)  ES 6.1\n(25 points)  \
# 0                  5.0                 3.0                 18.0
# 1                  9.0                 3.0                 13.0
# 2                  0.0                 3.0                 17.0
# 3                 10.0                 1.5                  7.0
# 4                  2.0                 3.0                 25.0
#
#    ES 6.2\n(15 points)  TOTAL\n(100 points)  label
# 0                   15                 85.0    0.0
# 1                   15                 82.0    0.0
# 2                   10                 52.5    1.0
# 3                   10                 59.0    1.0
# 4                   15                 90.0    0.0

# %%
Good = np.array(Good)
Fair = np.array(Fair)
Weak = np.array(Weak)

args = (Good, Fair, Weak)
x_total = np.concatenate(args)
x_total.shape
# Out:
# (52, 18)

# %%
y_good = []
y_fair = []
y_weak = []

for i in range(len(Good)):
 y_good.append(0)
 
for i in range(len(Fair)):
 y_fair.append(1) 

 
for i in range(len(Weak)):
 y_weak.append(2)  


y_good = np.array(y_good)
y_fair = np.array(y_fair)
y_weak = np.array(y_weak)

print("Shape of y_good :", y_good.shape)
print("Shape of y_fair :", y_fair.shape)
print("Shape of y_weak :", y_weak.shape)

args = (y_good, y_fair, y_weak)
y_total = np.concatenate(args)
y_total.shape
# Out:
# Shape of y_good : (24,)
# Shape of y_fair : (10,)
# Shape of y_weak : (18,)
# (52,)

# %%
x=x_total
y= y_total
print(x.shape)
print(y.shape)
# Out:
# (52, 18)
# (52,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=0)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (36, 17)
# (36,)
# (16, 17)
# (16,)

# %%
##Feature Scaling
# Standardization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_train)
x_train_sc=sc.transform(x_train)
x_test_sc=sc.transform(x_test)
# Normaization
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler()
mms.fit(x_train)
x_train_mms=mms.transform(x_train)
x_test_mms=mms.transform(x_test)

# %%
y
# Out:
# [24, 10, 18]

# %%
from sklearn.linear_model import LogisticRegression
l=LogisticRegression()
l.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
train_pred = l.predict(x_train)

# %%
test_pred = l.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
train_accur = accuracy_score(y_train,train_pred)
test_accur = accuracy_score(y_test,test_pred)

# %%
train_accur
# Out:
# 1.0

# %%
test_accur
# Out:
# 0.8125

# %%
# feature extraction

from sklearn.decomposition import PCA

pca = PCA(n_components = None)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)

# %%
# modelling

from sklearn.linear_model import LinearRegression

lmodel = LinearRegression()
lmodel.fit(x_train, y_train)

y_pred =lmodel.predict(x_test)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE Score : 0.360706452238682
# R2 Score : 0.8179893932252795

# %%
# modelling

from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

permodel = Perceptron()

# Train the model
permodel.fit(x_train, y_train)

y_pred = permodel.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# Accuracy: 0.8125
# RMSE Score : 0.4330127018922193
# R2 Score : 0.7

# %%
# modelling

from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE Score : 0.0
# R2 Score : 1.0

# %%
# modelling

from sklearn.svm import SVR

svrmodel = SVR()
svrmodel.fit(x_train, y_train)

y_pred = svrmodel.predict(x_test)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE Score : 0.21208264593414086
# R2 Score : 0.9370784892412837

# %%
df.head()
# Out:
#    Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  ES 2.1\n(2 points)  \
# 0           3                  2.0                    3                 1.0
# 1           6                  2.0                    3                 2.0
# 2           7                  2.0                    3                 1.0
# 3          10                  2.0                    3                 2.0
# 4          13                  2.0                    3                 2.0
#
#    ES 2.2\n(3 points)  ES 3.1\n(1 points)  ES 3.2\n(2 points)  \
# 0                 2.0                   1                   2
# 1                 3.0                   1                   2
# 2                 1.5                   1                   2
# 3                 1.5                   1                   2
# 4                 1.5                   1                   2
#
#    ES 3.3\n(2 points)  ES 3.4\n(2 points)  ES 3.5\n(3 points)  \
# 0                   2                 2.0                 3.0
# 1                   2                 0.0                 3.0
# 2                   0                 0.0                 3.0
# 3                   0                 2.0                 3.0
# 4                   2                 2.0                 3.0
#
#    ES 4.1\n(15 points)  ES 4.2\n(10 points)  ES 5.1\n(2 points)  \
# 0                 15.0                 10.0                   1
# 1                 15.0                  7.0                   2
# 2                  5.0                  4.0                   0
# 3                 11.0                  1.0                   2
# 4                 14.5                 10.0                   2
#
#    ES 5.2\n(10 points)  ES 5.3\n(3 points)  ES 6.1\n(25 points)  \
# 0                  5.0                 3.0                 18.0
# 1                  9.0                 3.0                 13.0
# 2                  0.0                 3.0                 17.0
# 3                 10.0                 1.5                  7.0
# 4                  2.0                 3.0                 25.0
#
#    ES 6.2\n(15 points)  TOTAL\n(100 points)  label
# 0                   15                 85.0    0.0
# 1                   15                 82.0    0.0
# 2                   10                 52.5    1.0
# 3                   10                 59.0    1.0
# 4                   15                 90.0    0.0

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn import metrics
x_train,x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)
adamodel = AdaBoostClassifier(n_estimators = 100 , learning_rate=1)


adamodel= adamodel.fit(x_train, y_train)
y_pred=model.predict(x_test)

print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.8829787234042553
# 0.09090909090909091

# %%
import pickle
with open('educte.pkl','wb') as files:
  pickle.dump(model,files)

# %%
model.predict([[76,76,74,72,76,23,76,78,67,67,67,45,56,56,67,67,67]])
# Out:
# array([1.])

# %%
x_train.shape
# Out:
# (41, 18)
